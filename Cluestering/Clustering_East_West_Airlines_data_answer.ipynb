# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel("EastWestAirlines.xlsx",1)

# %% [markdown]
# # EDA

# %%
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airlines_data=df.copy()

# %%
airlines_data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
airlines_data.corr()
# Out:
#                         ID#   Balance  Qual_miles  cc1_miles  cc2_miles  \
# ID#                1.000000 -0.243737   -0.019374  -0.224465   0.020291
# Balance           -0.243737  1.000000    0.108722   0.338344  -0.008804
# Qual_miles        -0.019374  0.108722    1.000000   0.007931  -0.013923
# cc1_miles         -0.224465  0.338344    0.007931   1.000000  -0.068223
# cc2_miles          0.020291 -0.008804   -0.013923  -0.068223   1.000000
# cc3_miles         -0.014707  0.035243   -0.007779   0.060555  -0.006166
# Bonus_miles       -0.203012  0.403487    0.031021   0.825200  -0.003969
# Bonus_trans       -0.146915  0.324935    0.050725   0.608943   0.064399
# Flight_miles_12mo -0.031013  0.217551    0.126774   0.037370   0.010598
# Flight_trans_12   -0.052096  0.255700    0.144004   0.041333   0.028284
# Days_since_enroll -0.964988  0.263129    0.017312   0.230849  -0.005807
# Award?            -0.177901  0.178494    0.095256   0.335457   0.005332
#
# ...

# %%
airlines_data[airlines_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID#, Balance, Qual_miles, cc1_miles, cc2_miles, cc3_miles, Bonus_miles, Bonus_trans, Flight_miles_12mo, Flight_trans_12, Days_since_enroll, Award?]
# Index: []

# %%
airlines_data.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %% [markdown]
# # Visualization

# %%
f, ax = plt.subplots(figsize=(15,5))
sns.barplot(x="Qual_miles",y="ID#",data=airlines_data)
# Out:
# <AxesSubplot:xlabel='Qual_miles', ylabel='ID#'>

# %%
f, ax = plt.subplots(figsize=(15,5))
sns.barplot(x="cc1_miles",y="ID#",data=airlines_data)
# Out:
# <AxesSubplot:xlabel='cc1_miles', ylabel='ID#'>

# %%
f, ax = plt.subplots(figsize=(15,5))
sns.barplot(x="cc2_miles",y="ID#",data=airlines_data)
# Out:
# <AxesSubplot:xlabel='cc2_miles', ylabel='ID#'>

# %%
f, ax = plt.subplots(figsize=(15,5))
sns.barplot(x="cc3_miles",y="ID#",data=airlines_data)
# Out:
# <AxesSubplot:xlabel='cc3_miles', ylabel='ID#'>

# %%
f, ax = plt.subplots(figsize=(15,5))
sns.barplot(x="Bonus_miles",y="ID#",data=airlines_data)
# Out:
# <AxesSubplot:xlabel='Bonus_miles', ylabel='ID#'>

# %%
f, ax = plt.subplots(figsize=(15,5))
sns.barplot(x="Bonus_trans",y="ID#",data=airlines_data)
# Out:
# <AxesSubplot:xlabel='Bonus_trans', ylabel='ID#'>

# %%
f, ax = plt.subplots(figsize=(15,5))
sns.barplot(x="Flight_miles_12mo",y="ID#",data=airlines_data)
# Out:
# <AxesSubplot:xlabel='Flight_miles_12mo', ylabel='ID#'>

# %%
f, ax = plt.subplots(figsize=(15,5))
sns.barplot(x="Flight_trans_12",y="ID#",data=airlines_data)
# Out:
# <AxesSubplot:xlabel='Flight_trans_12', ylabel='ID#'>

# %%
airlines_data.Days_since_enroll.hist()
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(airlines_data)

# %%
columns = airlines_data.columns

# %%
scaled_df = pd.DataFrame(data=scaled_data,columns=columns)
scaled_df
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     0.000000  0.016508         0.0       0.00        0.0        0.0
# 1     0.000249  0.011288         0.0       0.00        0.0        0.0
# 2     0.000498  0.024257         0.0       0.00        0.0        0.0
# 3     0.000746  0.008667         0.0       0.00        0.0        0.0
# 4     0.000995  0.057338         0.0       0.75        0.0        0.0
# ...        ...       ...         ...        ...        ...        ...
# 3994  0.999005  0.010837         0.0       0.00        0.0        0.0
# 3995  0.999254  0.037766         0.0       0.00        0.0        0.0
# 3996  0.999502  0.043169         0.0       0.50        0.0        0.0
# 3997  0.999751  0.032202         0.0       0.00        0.0        0.0
# 3998  1.000000  0.001769         0.0       0.00        0.0        0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %% [markdown]
# # Dendogram

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
dendrogram = sch.dendrogram(sch.linkage(scaled_df, method='average'))

# %% [markdown]
# # K-Means Clustering

# %%
from sklearn.cluster import KMeans

# %%
airlines_data1=df.copy()

# %%
airlines_data1.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
# Standarization function
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_airlines_df = scaler.fit_transform(airlines_data1)

# %%
pd.DataFrame(scaled_airlines_df)
# Out:
#             0         1         2         3         4         5         6   \
# 0    -1.735125 -0.451141 -0.186299 -0.769578 -0.098242 -0.062767 -0.702786
# 1    -1.734263 -0.539457 -0.186299 -0.769578 -0.098242 -0.062767 -0.701088
# 2    -1.733402 -0.320031 -0.186299 -0.769578 -0.098242 -0.062767 -0.539253
# 3    -1.732540 -0.583799 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286
# 4    -1.731679  0.239678 -0.186299  1.409471 -0.098242 -0.062767  1.083121
# ...        ...       ...       ...       ...       ...       ...       ...
# 3994  1.725097 -0.547079 -0.186299 -0.769578 -0.098242 -0.062767 -0.356960
# 3995  1.725958 -0.091465 -0.186299 -0.769578 -0.098242 -0.062767 -0.669367
# 3996  1.726820 -0.000043 -0.186299  0.683121 -0.098242 -0.062767  0.343804
# 3997  1.727682 -0.185607 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286
# 3998  1.728543 -0.700508 -0.186299 -0.769578 -0.098242 -0.062767 -0.709992
#
#             7         8         9         10        11
# ...

# %%
kmeans = KMeans(n_clusters=3,random_state=0)
kmeans.fit(scaled_airlines_df)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
airlines_data1["Cluster"] = kmeans.predict(scaled_airlines_df)

# %%
airlines_data1.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    Cluster
# 0        0
# 1        0
# 2        0
# ...

# %% [markdown]
# # Elbow Graph

# %%
kmeans.inertia_
# Out:
# 34529.16866611334

# %%
wcss = []
for i in range(2,11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(scaled_airlines_df)
    dist = kmeans.inertia_
    wcss.append(dist)

# %%
wcss
# Out:
# [39018.84742954434,
#  34529.16866611334,
#  30616.623636092638,
#  26894.753059893224,
#  23490.74902876985,
#  21885.368244869307,
#  19330.695176303714,
#  18015.30065898044,
#  16846.161847375995]

# %%
plt.plot(range(2,11),wcss)
plt.title("Elbow Method")
plt.xlabel("Number of cluster")
plt.ylabel("Within a cluster sum of square")
plt.grid()

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(scaled_airlines_df)
    wcss.append(kmeans.inertia_)
    if i > 6:
      break

# %%
#Build Cluster algorithm
from sklearn.cluster import KMeans
clusters = KMeans(6, random_state=0)
clusters.fit(scaled_airlines_df)
# Out:
# KMeans(n_clusters=6, random_state=0)

# %%
clusters.labels_
# Out:
# array([2, 2, 2, ..., 1, 1, 1])

# %%
#Assign clusters to the data set
airlines_data1['clusternew'] = clusters.labels_

# %%
airlines_data1.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    Cluster  clusternew
# 0        0           2
# ...

# %%
clusters.cluster_centers_
# Out:
# array([[-0.23852715,  1.18446344,  0.88037642,  0.11446574, -0.09824189,
#         -0.06276658,  0.63780138,  1.65423176,  3.64043543,  3.92064625,
#          0.275472  ,  0.9224481 ],
#        [ 0.96803202, -0.33839012, -0.05974896, -0.50115538, -0.09824189,
#         -0.06276658, -0.46151109, -0.41763139, -0.18820091, -0.207612  ,
#         -0.95928629, -0.35719626],
#        [-0.792215  , -0.16310888, -0.05017319, -0.50959763, -0.09824189,
#         -0.05874576, -0.47211132, -0.39177122, -0.16556507, -0.17590564,
#          0.7709545 , -0.25164813],
#        [-0.39326741,  0.51242422,  0.02653687,  1.35981814, -0.09824189,
#         -0.05276166,  1.12237626,  0.79890128, -0.06452417, -0.07095245,
#          0.39623627,  0.68913829],
#        [-0.30152248,  0.63971926, -0.08443292,  1.0220844 , -0.09824189,
#         15.64629931,  3.17969131,  1.71461374,  0.03329269,  0.05969539,
#          0.23987261,  0.33752735],
# ...

# %% [markdown]
# #  DBSCAN

# %%
df.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
df.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
airlines=df.copy()

# %%
airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
#Standarization (z-score)
from sklearn.preprocessing import StandardScaler
stscaler = StandardScaler()
x = stscaler.fit_transform(airlines)

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(eps=2.3, min_samples=13)
dbscan.fit(x)
# Out:
# DBSCAN(eps=2.3, min_samples=13)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
airlines["-1_outlier"] = dbscan.labels_

# %%
airlines
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airlines['-1_outlier'].value_counts()
# Out:
#  0    3759
# -1     221
#  1      19
# Name: -1_outlier, dtype: int64

# %%
airlines[airlines["-1_outlier"]==-1]
# These are the outliers
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 8        9   443003           0          3          2          1         1753
# 50      51   108137           0          1          1          1         6368
# 65      66    53914           0          3          1          1        33767
# 70      72    84409        5031          2          1          1        15436
# 87      90   609477           0          3          1          1        21422
# ...    ...      ...         ...        ...        ...        ...          ...
# 3883  3906   126167           0          5          1          1       190160
# 3897  3920   179832        2954          3          1          1        18218
# 3911  3934    55922        2273          1          1          1         8104
# 3917  3940   130748           0          4          1          1        65510
# 3934  3957    76595           0          1          1          1        10577
#
# ...

# %%
airlines[airlines["-1_outlier"]==1].index
# Out:
# Int64Index([ 794, 1149, 1383, 1389, 1527, 1541, 1976, 2006, 2317, 2421, 2557,
#             2741, 2906, 2967, 3155, 3191, 3359, 3487, 3959],
#            dtype='int64')

# %%
airlines[airlines["-1_outlier"]==0]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airlines[airlines["-1_outlier"]==1]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 794    804    55610           0          1          2          1         5095
# 1149  1161    84856           0          1          2          1         6894
# 1383  1397    18154           0          1          2          1         7748
# 1389  1403    49145           0          1          2          1        12755
# 1527  1542    23965           0          1          2          1         7308
# 1541  1556    36887           0          1          2          1         9048
# 1976  1993    11961           0          1          2          1        11961
# 2006  2023   101901           0          1          2          1        17898
# 2317  2335    10458           0          1          2          1        10458
# 2421  2440    41062           0          1          2          1         8275
# 2557  2576    42966           0          1          2          1         7734
# ...

# %% [markdown]
# # Silhouette Score

# %%
dl=dbscan.labels_

# %%
import sklearn
sklearn.metrics.silhouette_score(x,dl)
# Out:
# 0.5066544550211249

# %%
clf=KMeans(n_clusters=3)
y_Kmeans1=clf.fit_predict(x)

# %%
y_Kmeans1
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
sklearn.metrics.silhouette_score(x,y_Kmeans1)
# Out:
# 0.28132087151477925

# %% [markdown]
# # From the above Silhouette score DBSCAM model is better model
