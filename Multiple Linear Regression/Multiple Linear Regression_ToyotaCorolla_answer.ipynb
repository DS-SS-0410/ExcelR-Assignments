# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import warnings
warnings.filterwarnings("ignore")

# %%
df1=pd.read_csv("ToyotaCorolla.csv",encoding= 'unicode_escape')

# %%
df1.head(5)
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
# 2          9      2002  41711    Diesel  90          1  ...            0
# 3          7      2002  48000    Diesel  90          0  ...            0
# 4          3      2002  38500    Diesel  90          0  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, Model, Price, Age_08_04, Mfg_Month, Mfg_Year, KM, Fuel_Type, HP, Met_Color, Color, Automatic, cc, Doors, Cylinders, Gears, Quarterly_Tax, Weight, Mfr_Guarantee, BOVAG_Guarantee, Guarantee_Period, ABS, Airbag_1, Airbag_2, Airco, Automatic_airco, Boardcomputer, CD_Player, Central_Lock, Powered_Windows, Power_Steering, Radio, Mistlamps, Sport_Model, Backseat_Divider, Metallic_Rim, Radio_cassette, Tow_Bar]
# Index: []
#
# [0 rows x 38 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
df=df1.loc[:, ("Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax",'Weight')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1436 non-null   int64
#  1   Age_08_04      1436 non-null   int64
#  2   KM             1436 non-null   int64
#  3   HP             1436 non-null   int64
#  4   cc             1436 non-null   int64
#  5   Doors          1436 non-null   int64
#  6   Gears          1436 non-null   int64
#  7   Quarterly_Tax  1436 non-null   int64
#  8   Weight         1436 non-null   int64
# dtypes: int64(9)
# memory usage: 101.1 KB

# %% [markdown]
# # Correlation Matrix

# %%
df.corr()
# Out:
#                   Price  Age_08_04        KM        HP        cc     Doors  \
# Price          1.000000  -0.876590 -0.569960  0.314990  0.126389  0.185326
# Age_08_04     -0.876590   1.000000  0.505672 -0.156622 -0.098084 -0.148359
# KM            -0.569960   0.505672  1.000000 -0.333538  0.102683 -0.036197
# HP             0.314990  -0.156622 -0.333538  1.000000  0.035856  0.092424
# cc             0.126389  -0.098084  0.102683  0.035856  1.000000  0.079903
# Doors          0.185326  -0.148359 -0.036197  0.092424  0.079903  1.000000
# Gears          0.063104  -0.005364  0.015023  0.209477  0.014629 -0.160141
# Quarterly_Tax  0.219197  -0.198431  0.278165 -0.298432  0.306996  0.109363
# Weight         0.581198  -0.470253 -0.028598  0.089614  0.335637  0.302618
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063104       0.219197  0.581198
# Age_08_04     -0.005364      -0.198431 -0.470253
# KM             0.015023       0.278165 -0.028598
# ...

# %%
sns.pairplot(df)

# %%
df.head(2)
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165

# %%
df.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'HP', 'cc', 'Doors', 'Gears',
#        'Quarterly_Tax', 'Weight'],
#       dtype='object')

# %% [markdown]
# # Model Building

# %%
model=smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=df).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     1131.
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):               0.00
# Time:                        14:24:48   Log-Likelihood:                -12376.
# No. Observations:                1436   AIC:                         2.477e+04
# Df Residuals:                    1427   BIC:                         2.482e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
#Doors is an insignificiat variable and it also does not affect in price, so we can drop Doors directly without cross-verification

# %% [markdown]
# # SLR Model

# %%
ml_cc=smf.ols('Price~cc',data=df).fit()
print(ml_cc.tvalues, '\n', ml_cc.pvalues)
# Out:
# Intercept    24.694090
# cc            4.824822
# dtype: float64
#  Intercept    1.766912e-112
# cc            1.550808e-06
# dtype: float64

# %%
#cc is significat

# %% [markdown]
# # Model Validation - QQ Plot

# %%
import statsmodels.api as sm

# %%
qqplot=sm.qqplot(model.resid,line='q')
plt.title('Normal Q-Q Plot of residuals')
plt.show()

# %% [markdown]
# # Residual Plot for Homoscedasticity

# %%
def zscore (vals):
    return(vals-vals.mean())
plt.scatter(zscore(model.fittedvalues),
            zscore(model.resid))
plt.title("Residual Plot")
plt.xlabel("Standardized Fitted Values")
plt.ylabel("Standardized Residual Values")
plt.show()

# %% [markdown]
# # Residual Vs Regressors

# %%
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,'Age_08_04',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,'KM',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,'HP',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,'cc',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,'Gears',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,'Quarterly_Tax',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,'Weight',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # Model Deletion Daignostics

# %% [markdown]
# # Cook's Distance

# %%
model_influence = model.get_influence()
(c,_)= model_influence.cooks_distance

# %%
fig = plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(df)),np.round(c,3))
plt.xlabel("Row Index")
plt.ylabel("Cooks Distance")
plt.show()

# %%
(np.argmax(c),np.max(c))
# Out:
# (80, 79.52010624137755)

# %%
df2 = df.drop(df.index[[80]],axis=0).reset_index()

# %% [markdown]
# # High Influence points

# %%
influence_plot(model)
plt.show()

# %%
k=8
n=df.shape[0]
leverage_cutoff=3*((k+1)/n)
leverage_cutoff
# Out:
# 0.018802228412256268

# %% [markdown]
# # Experimenting Model building

# %%
finalmodel=smf.ols('Price~Age_08_04+KM+HP+cc+Gears+Quarterly_Tax+Weight',data=df2).fit()

# %%
finalmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.869
# Method:                 Least Squares   F-statistic:                     1356.
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):               0.00
# Time:                        14:24:55   Log-Likelihood:                -12335.
# No. Observations:                1435   AIC:                         2.469e+04
# Df Residuals:                    1427   BIC:                         2.473e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
df2.shape
# Out:
# (1435, 10)

# %%
model_influence_V = finalmodel.get_influence()
(c_V,_)= model_influence_V.cooks_distance

# %%
fig = plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(df2)),np.round(c_V,3))
plt.xlabel("Row Index")
plt.ylabel("Cooks Distance")
plt.show()

# %%
(np.argmax(c_V),np.max(c_V))
# Out:
# (220, 2.3034451664541264)

# %%
df3 = df2.drop(df2.index[[220]],axis=0).reset_index()

# %%
df3.shape
# Out:
# (1434, 11)

# %%
df3.head(2)
# Out:
#    level_0  index  Price  Age_08_04     KM  HP    cc  Doors  Gears  \
# 0        0      0  13500         23  46986  90  2000      3      5
# 1        1      1  13750         23  72937  90  2000      3      5
#
#    Quarterly_Tax  Weight
# 0            210    1165
# 1            210    1165

# %%
df3=df3.drop("index",axis=1)

# %%
df3=df3.drop("level_0",axis=1)

# %%
df3.head(3)
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165
# 2  13950         24  41711  90  2000      3      5            210    1165

# %%
finalmodel1=smf.ols('Price~Age_08_04+KM+HP+cc+Gears+Quarterly_Tax+Weight',data=df3).fit()

# %%
finalmodel1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     1461.
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):               0.00
# Time:                        14:35:23   Log-Likelihood:                -12280.
# No. Observations:                1434   AIC:                         2.458e+04
# Df Residuals:                    1426   BIC:                         2.462e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
model_influence_V1 = finalmodel1.get_influence()
(c_V1,_)= model_influence_V1.cooks_distance

# %%
fig = plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(df3)),np.round(c_V1,3))
plt.xlabel("Row Index")
plt.ylabel("Cooks Distance")
plt.show()

# %%
(np.argmax(c_V1),np.max(c_V1))
# Out:
# (958, 2.290715916304523)

# %%
# cook's distance value >1

# %%
df4 = df3.drop(df3.index[[958]],axis=0).reset_index()

# %%
df4.shape
# Out:
# (1433, 10)

# %%
df4.head(1)
# Out:
#    index  Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  \
# 0      0  13500         23  46986  90  2000      3      5            210
#
#    Weight
# 0    1165

# %%
df4=df4.drop("index",axis=1)

# %% [markdown]
# # Final Model Building

# %%
finalmodel2=smf.ols('Price~Age_08_04+KM+HP+cc+Gears+Quarterly_Tax+Weight',data=df4).fit()

# %%
finalmodel2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.884
# Model:                            OLS   Adj. R-squared:                  0.884
# Method:                 Least Squares   F-statistic:                     1556.
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):               0.00
# Time:                        14:41:27   Log-Likelihood:                -12231.
# No. Observations:                1433   AIC:                         2.448e+04
# Df Residuals:                    1425   BIC:                         2.452e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
model_influence_V2 = finalmodel2.get_influence()
(c_V2,_)= model_influence_V2.cooks_distance

# %%
fig = plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(df4)),np.round(c_V2,3))
plt.xlabel("Row Index")
plt.ylabel("Cooks Distance")
plt.show()

# %%
(np.argmax(c_V2),np.max(c_V2))
# Out:
# (599, 0.2877229363895601)

# %% [markdown]
# # cook's distance is < 1. so stop here no more influencing observation for us.

# %% [markdown]
# # Prediction

# %%
newdata= pd.DataFrame({"Age_08_04":12,"KM":33000,'cc':1800,"HP":90,'Quarterly_Tax':220,"Gears":5,"Weight":1240},index=[1])

# %%
finalmodel2.predict(newdata)
# Out:
# 1    20662.553191
# dtype: float64
